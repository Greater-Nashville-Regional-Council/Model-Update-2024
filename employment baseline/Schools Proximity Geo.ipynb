# %%
import pandas as pd
import numpy as np
import geopandas as gpd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 150)
from warnings import simplefilter
simplefilter(action="ignore", category=pd.errors.PerformanceWarning)

# %%
parcels = gpd.read_file('../data/Geo/ParcelCenterPts_projected.shp')

# %%
#parcels_proj = parcels.to_crs(epsg=26916)

# %%
parcels.head()
# Out:
#     COUNTY          GISLINK  GISLINK_X  GISLINK_Y          X          Y                        geometry
# 0  STEWART  081055    00401   4.016667   8.181944 -87.800331  36.554674  POINT (1439711.524 813466.205)
# 1   WILSON  095016    00100   1.000000   9.837778 -86.287792  36.326106  POINT (1883722.463 725513.148)
# 2   WILSON  095115    02401  24.016667   9.854167 -86.344029  36.102465  POINT (1866869.567 644152.603)
# 3   WILSON  095019    00805   8.083333   9.838611 -86.169753  36.321454  POINT (1918491.722 723738.057)
# 4  STEWART  081140    00310   3.166667   8.194444 -87.627314  36.369018  POINT (1489401.120 744994.011)

# %%
schools = gpd.read_file('../data/Geo/Schools_Projected.shp')

# %%
schools.head()
# Out:
#    OBJECTID_1       NCESSCH   SURVYEAR STABR    LEAID  ST_LEAID        LEA_NAME                  SCH_NAME                      LSTREET1 LSTREET2  \
# 0       79275  470000100477  2021-2022    TN  4700001  TN-00320  Hamblen County          Alpha Elementary          5620 Old Us  11e HWY     None
# 1       79276  470000100479  2021-2022    TN  4700001  TN-00320  Hamblen County  East Ridge Middle School             6595 St. Clair RD     None
# 2       79277  470000100480  2021-2022    TN  4700001  TN-00320  Hamblen County       Fairview Marguerite            2125  Fairview  RD     None
# 3       79278  470000100481  2021-2022    TN  4700001  TN-00320  Hamblen County         Manley Elementary         551  West  Economy RD     None
# 4       79279  470000100483  2021-2022    TN  4700001  TN-00320  Hamblen County   Russellville Elementary  5655  Old  Russellville PIKE     None
#
# ...

# %%
# schools_proj = schools.to_crs("EPSG:4326")
# schools_proj = schools_proj.to_crs(epsg=26916)

# %%
schools.crs
# Out:
# <Projected CRS: EPSG:6576>
# Name: NAD83(2011) / Tennessee (ftUS)
# Axis Info [cartesian]:
# - X[east]: Easting (US survey foot)
# - Y[north]: Northing (US survey foot)
# Area of Use:
# ...

# %%
test = gpd.sjoin_nearest(parcels, schools, how = 'inner', max_distance = None, lsuffix = 'Parcels ', rsuffix = 'Schools ', distance_col = 'Distance')

# %%
test.head()
# Out:
#        COUNTY          GISLINK  GISLINK_X  GISLINK_Y          X          Y                        geometry  index_Schools   OBJECTID_1  \
# 0     STEWART  081055    00401   4.016667   8.181944 -87.800331  36.554674  POINT (1439711.524 813466.205)            1649       80924
# 855   STEWART  081046    00400   4.000000   8.179444 -87.862147  36.576743  POINT (1421710.152 821839.431)            1649       80924
# 1359  STEWART  081018    00200   2.000000   8.171667 -87.858261  36.626324  POINT (1423193.906 839866.365)            1649       80924
# 1443  STEWART  081045    01802  18.033333   8.179167 -87.818725  36.565295  POINT (1434381.506 817432.474)            1649       80924
# 1444  STEWART  081045    01802  18.033333   8.179167 -87.818725  36.565295  POINT (1434381.506 817432.474)            1649       80924
#
#            NCESSCH   SURVYEAR STABR    LEAID  ST_LEAID        LEA_NAME                          SCH_NAME               LSTREET1 LSTREET2  LCITY  \
# ...

# %%
test.to_file('../data/Geo/test.shp')
# Out:
# C:\Users\jmccall\AppData\Local\Temp\ipykernel_18896\2221609178.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   test.to_file('../data/Geo/test.shp')
